# %% [markdown]
# <a href="https://colab.research.google.com/github/DmitryFrom4e/GeekBrains_Python-_DZ/blob/master/lesson_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# читаем данные
df = pd.read_csv('sample_data/california_housing_test.csv')

# %%
# df.head() первые 5 строк во фрейме
df.head(n = 10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
# df.tail() последние по умолч 5 строк во фрейме
df.tail(n = 2)
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %%
df.shape
# Out:
# (3000, 9)

# %%
# null в ячейках
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
# кол-во null в ячейках
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# типы ячеек во фрейме
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
# получение столбцов
df.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
# выборка данных
df['latitude'] #1 столбец
# Out:
# 0       37.37
# 1       34.26
# 2       33.78
# 3       33.82
# 4       36.33
#         ...
# 2995    34.42
# 2996    34.06
# 2997    36.30
# 2998    34.10
# 2999    34.42
# Name: latitude, Length: 3000, dtype: float64

# %%
df[['latitude', 'population']] #2 столбца
# Out:
#       latitude  population
# 0        37.37      1537.0
# 1        34.26       809.0
# 2        33.78      1484.0
# 3        33.82        49.0
# 4        36.33       850.0
# ...        ...         ...
# 2995     34.42      1258.0
# 2996     34.06      3496.0
# 2997     36.30       693.0
# 2998     34.10        46.0
# 2999     34.42       753.0
#
# [3000 rows x 2 columns]

# %%
# & выполнение одновременно всех условий
# | выполнение хотя бы одного условия
df[df['housing_median_age'] < 20]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
# 2997    -119.70     36.30                10.0        956.0           201.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df['housing_median_age'] < 20]['total_rooms']
# Out:
# 4       1241.0
# 7       2310.0
# 8       3080.0
# 13      3936.0
# 16       570.0
#          ...
# 2981    4422.0
# 2984    3239.0
# 2985    1368.0
# 2991    4867.0
# 2997     956.0
# Name: total_rooms, Length: 830, dtype: float64

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 10)]['total_rooms']
# Out:
# 4       1241.0
# 7       2310.0
# 8       3080.0
# 13      3936.0
# 16       570.0
#          ...
# 2978    2761.0
# 2981    4422.0
# 2984    3239.0
# 2985    1368.0
# 2991    4867.0
# Name: total_rooms, Length: 616, dtype: float64

# %%
df[(df['housing_median_age'] < 20) & (df['housing_median_age'] > 10)][['total_rooms', 'housing_median_age']]
# Out:
#       total_rooms  housing_median_age
# 4          1241.0                19.0
# 7          2310.0                19.0
# 8          3080.0                15.0
# 13         3936.0                16.0
# 16          570.0                15.0
# ...           ...                 ...
# 2978       2761.0                17.0
# 2981       4422.0                17.0
# 2984       3239.0                13.0
# 2985       1368.0                17.0
# 2991       4867.0                13.0
#
# [616 rows x 2 columns]

# %%
# статистика
# count - общее кол-во не пустых строк
# mean - среднее значение в столбце
# std - стандартное отклонение от среднего значения
# 

print(df['population'].max())
# Out:
# 11935.0

# %%
print(df['population'].min())
# Out:
# 5.0

# %%
print(df['population'].mean()) #среднее
# Out:
# 1402.7986666666666

# %%
print(df['population'].sum())
# Out:
# 4208396.0

# %%
df[['population', 'total_rooms']].median()
# Out:
# population     1155.0
# total_rooms    2106.0
# dtype: float64

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...
